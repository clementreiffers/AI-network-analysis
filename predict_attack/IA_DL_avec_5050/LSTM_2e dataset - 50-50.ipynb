# %%
import pandas as pd
import numpy as np

# Graph
import plotly.express as px
import matplotlib.pyplot as plt

# Keras
from keras.models import Sequential
from keras.layers import Dense
from keras import callbacks

# sklearn
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score

# tf
from tensorflow.keras.utils import to_categorical
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Dropout, LSTM
from tensorflow.keras.layers import Embedding
from tensorflow.keras.optimizers import SGD

# %%
path = r"C:\Users\sonia\Documents\Document\2022-2023\Projet 3I - Deep Learning\dataset_clean.csv"
TARGET = 'Label'

# %%
df = pd.read_csv(path)

# %%
df = df[['Init_Win_bytes_forward',
'Total Length of Fwd Packets',
'Bwd Header Length',
'Destination Port',
'Subflow Fwd Bytes',
'Packet Length Std',
'Packet Length Variance',
'Bwd Packets/s',
'Average Packet Size',
'Bwd Packet Length Std',
         "Label"]]

# %%
df_b = df[df['Label']==1]
df_a = df[df['Label']==0]

# %%
df_b= df_b[0:2241]

# %%
df = pd.concat([df_a, df_b], axis=0)

# %%
df = df.sample(frac=1)

# %%
y = df[TARGET]
X = df.drop([TARGET],axis=1)

# %%
y = y.to_numpy()
scaler = StandardScaler()
scaler.fit(X)
X = scaler.transform(X)
y = to_categorical(y)

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.2)

# %%
X_train = np.reshape(X_train, (X_train.shape[0], 1, X.shape[1]))
X_test = np.reshape(X_test, (X_test.shape[0], 1, X.shape[1]))

# %% [markdown]
# ## Model

# %%
model = Sequential()

model.add(LSTM(128, input_shape=(1, 10),activation="relu",return_sequences=True))
model.add(LSTM(128,activation="relu"))
model.add(Dense(y.shape[1], activation='sigmoid'))

model.compile(loss = 'binary_crossentropy', optimizer = "adam", metrics = ['accuracy'])

model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  lstm (LSTM)                 (None, 1, 128)            71168
#
#  lstm_1 (LSTM)               (None, 128)               131584
#
#  dense (Dense)               (None, 2)                 258
#
# =================================================================
# Total params: 203,010
# Trainable params: 203,010
# Non-trainable params: 0
# _________________________________________________________________

# %%
earlystopping = callbacks.EarlyStopping(monitor ="val_loss", 
                                        mode ="min", 
                                        patience = 3, 
                                        restore_best_weights = True)

# %%
history = model.fit(X_train, y_train, 
                    epochs = 25, 
                    validation_data= (X_test, y_test),
                    callbacks =[earlystopping])
history
# Out:
# Epoch 1/25
# 113/113 [==============================] - 4s 9ms/step - loss: 0.5537 - accuracy: 0.7590 - val_loss: 0.4186 - val_accuracy: 0.8105
# Epoch 2/25
# 113/113 [==============================] - 1s 6ms/step - loss: 0.3810 - accuracy: 0.8399 - val_loss: 0.3398 - val_accuracy: 0.8673
# Epoch 3/25
# 113/113 [==============================] - 1s 5ms/step - loss: 0.3273 - accuracy: 0.8572 - val_loss: 0.2988 - val_accuracy: 0.8673
# Epoch 4/25
# 113/113 [==============================] - 1s 5ms/step - loss: 0.2968 - accuracy: 0.8566 - val_loss: 0.2723 - val_accuracy: 0.8595
# Epoch 5/25
# 113/113 [==============================] - 1s 5ms/step - loss: 0.2729 - accuracy: 0.8672 - val_loss: 0.2462 - val_accuracy: 0.8696
# Epoch 6/25
# 113/113 [==============================] - 1s 5ms/step - loss: 0.2562 - accuracy: 0.8695 - val_loss: 0.2434 - val_accuracy: 0.8986
# Epoch 7/25
# 113/113 [==============================] - 1s 7ms/step - loss: 0.2498 - accuracy: 0.8946 - val_loss: 0.2291 - val_accuracy: 0.9119
# Epoch 8/25
# 113/113 [==============================] - 1s 7ms/step - loss: 0.2402 - accuracy: 0.8934 - val_loss: 0.2190 - val_accuracy: 0.9019
# Epoch 9/25
# 113/113 [==============================] - 1s 6ms/step - loss: 0.2250 - accuracy: 0.8954 - val_loss: 0.2120 - val_accuracy: 0.9108
# Epoch 10/25
# 113/113 [==============================] - 1s 6ms/step - loss: 0.2185 - accuracy: 0.9021 - val_loss: 0.2042 - val_accuracy: 0.9075
# Epoch 11/25
# 113/113 [==============================] - 1s 7ms/step - loss: 0.2098 - accuracy: 0.9077 - val_loss: 0.2029 - val_accuracy: 0.8885
# Epoch 12/25
# 113/113 [==============================] - 1s 8ms/step - loss: 0.2106 - accuracy: 0.9060 - val_loss: 0.2168 - val_accuracy: 0.8774
# Epoch 13/25
# 113/113 [==============================] - 1s 6ms/step - loss: 0.2106 - accuracy: 0.9021 - val_loss: 0.1939 - val_accuracy: 0.9186
# Epoch 14/25
# 113/113 [==============================] - 1s 6ms/step - loss: 0.2057 - accuracy: 0.9088 - val_loss: 0.1924 - val_accuracy: 0.9119
# Epoch 15/25
# 113/113 [==============================] - 1s 6ms/step - loss: 0.2045 - accuracy: 0.9121 - val_loss: 0.2225 - val_accuracy: 0.9097
# Epoch 16/25
# 113/113 [==============================] - 1s 6ms/step - loss: 0.1966 - accuracy: 0.9135 - val_loss: 0.1980 - val_accuracy: 0.9220
# Epoch 17/25
# 113/113 [==============================] - 1s 6ms/step - loss: 0.1970 - accuracy: 0.9169 - val_loss: 0.1925 - val_accuracy: 0.9253

# %%
accuracy = model.evaluate(X_test, y_test)
accuracy # 0.9119
# Out:
# 29/29 [==============================] - 0s 2ms/step - loss: 0.1924 - accuracy: 0.9119
# [0.19236263632774353, 0.911928653717041]

# %%
# loss plot function
def plot_loss(loss,val_loss):
    plt.figure()
    plt.plot(loss)
    plt.plot(val_loss)
    plt.title('Model loss')
    plt.ylabel('Loss')
    plt.xlabel('Epoch')
    plt.legend(['Train', 'Test'], loc='upper right')  
    plt.show()
    
# accuracy plot function    
def plot_accuracy(acc,val_acc):
    plt.figure()
    plt.plot(acc)
    plt.plot(val_acc)
    plt.title('Model accuracy')
    plt.ylabel('Accuracy')
    plt.xlabel('Epoch')
    plt.legend(['Train', 'Test'], loc='upper left')
    plt.show()

# plot loss and accuracy curves
plot_loss(history.history['loss'], history.history['val_loss'])
plot_accuracy(history.history['accuracy'], history.history['val_accuracy'])
