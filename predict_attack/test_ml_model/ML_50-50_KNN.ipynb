# %%
import pandas as pd
from sklearn.decomposition import PCA
from sklearn.model_selection import train_test_split
from sklearn.neighbors import KNeighborsClassifier
from sklearn.pipeline import make_pipeline
from sklearn.preprocessing import StandardScaler

# %%
path = r"C:\Users\sonia\Documents\Document\2022-2023\Projet 3I - Deep Learning\dataset_clean.csv"
TARGET = 'Label'

# %%
df = pd.read_csv(path)

# %%
df = df[['Init_Win_bytes_forward',
'Total Length of Fwd Packets',
'Bwd Header Length',
'Destination Port',
'Subflow Fwd Bytes',
'Packet Length Std',
'Packet Length Variance',
'Bwd Packets/s',
'Average Packet Size',
'Bwd Packet Length Std',
         "Label"]]

# %%
df.head()
# Out:
#    Init_Win_bytes_forward  Total Length of Fwd Packets  Bwd Header Length  \
# 0                      -1                           68                 40
# 1                      -1                           90                 64
# 2                   29200                            0                 20
# 3                     440                            6                 20
# 4                     251                            0                  0
#
#    Destination Port  Subflow Fwd Bytes  Packet Length Std  \
# 0                53                 68          54.224533
# 1                53                 90          20.813457
# 2              7496                  0           3.464102
# 3             46564                  6           0.000000
# 4                80                  0           0.000000
#
#    Packet Length Variance  Bwd Packets/s  Average Packet Size  \
# 0                  2940.3   12578.616350                92.00
# 1                   433.2      38.704933                75.25
# 2                    12.0   23255.813950                 3.00
# 3                     0.0   16393.442620                 9.00
# 4                     0.0       0.000000                 0.00
#
#    Bwd Packet Length Std  Label
# 0                    0.0      1
# 1                    0.0      1
# 2                    0.0      0
# 3                    0.0      1
# 4                    0.0      1

# %%
df.describe()
# Out:
#        Init_Win_bytes_forward  Total Length of Fwd Packets  Bwd Header Length  \
# count            24747.000000                 2.474700e+04       2.474700e+04
# mean              7147.320483                 5.938086e+02       3.788556e+02
# std              14857.013084                 7.826002e+03       3.269787e+04
# min                 -1.000000                 0.000000e+00       0.000000e+00
# 25%                 -1.000000                 1.200000e+01       2.000000e+01
# 50%                235.000000                 6.500000e+01       4.000000e+01
# 75%               8192.000000                 1.870000e+02       9.200000e+01
# max              65535.000000                 1.162781e+06       5.134800e+06
#
#        Destination Port  Subflow Fwd Bytes  Packet Length Std  \
# count      24747.000000       2.474700e+04       24747.000000
# mean        8902.282176       5.938086e+02         224.007815
# std        19203.186702       7.826002e+03         500.900499
# min            0.000000       0.000000e+00           0.000000
# 25%           53.000000       1.200000e+01           2.190890
# 50%           80.000000       6.500000e+01          27.933850
# 75%          443.000000       1.870000e+02         141.312420
# max        65464.000000       1.162781e+06        4380.487987
#
#        Packet Length Variance   Bwd Packets/s  Average Packet Size  \
# count            2.474700e+04    24747.000000         24747.000000
# mean             3.010688e+05     6987.977061           159.900119
# std              1.251259e+06    39477.504710           275.068647
# min              0.000000e+00        0.000000             0.000000
# 25%              4.800000e+00        0.194312             9.000000
# 50%              7.803000e+02       21.847179            74.750000
# 75%              1.996920e+04     6578.947368           138.240385
# max              1.920000e+07  1000000.000000          2251.333333
#
#        Bwd Packet Length Std         Label
# count           24747.000000  24747.000000
# mean              231.238145      0.909444
# std               628.988988      0.286983
# min                 0.000000      0.000000
# 25%                 0.000000      1.000000
# 50%                 0.000000      1.000000
# 75%                24.145171      1.000000
# max              6692.644993      1.000000

# %%
df_b = df[df['Label']==1]
df_a = df[df['Label']==0]

# %%
df_a.shape
# Out:
# (2241, 11)

# %%
df_b.shape
# Out:
# (22506, 11)

# %%
df_b= df_b[0:2241]

# %%
df_b.shape
# Out:
# (2241, 11)

# %%
df = pd.concat([df_a, df_b], axis=0)

# %%
df = df.sample(frac=1)

# %%
y = df[TARGET]
X = df.drop([TARGET],axis=1)

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.2)

# %%
for k in range(1, 10):
    scaler = StandardScaler()
    pca = PCA()
    knn = KNeighborsClassifier(k)
    knn2 = KNeighborsClassifier(k)

    pipeline = make_pipeline(scaler, pca, knn)

    pipeline.fit(X_train, y_train)
    knn2.fit(X_train, y_train)

    print(f"*********************** {k} ***********************")

    print("--- TRAIN ---")
    print("avec standardisation et pca : ", pipeline.score(X_train, y_train))
    print("knn seul : ", knn2.score(X_train, y_train))

    print("--- TEST ---")
    print("avec standardisation et pca : ", pipeline.score(X_test, y_test))
    print("knn seul : ", knn2.score(X_test, y_test))
# Out:
# *********************** 1 ***********************
# --- TRAIN ---
# avec standardisation et pca :  0.999721059972106
# knn seul :  0.999721059972106
# --- TEST ---
# avec standardisation et pca :  0.9632107023411371
# knn seul :  0.9464882943143813
# *********************** 2 ***********************
# --- TRAIN ---
# avec standardisation et pca :  0.9827057182705718
# knn seul :  0.9748953974895398
# --- TEST ---
# avec standardisation et pca :  0.9576365663322185
# knn seul :  0.939799331103679
# *********************** 3 ***********************
# --- TRAIN ---
# avec standardisation et pca :  0.9824267782426779
# knn seul :  0.9737796373779637
# --- TEST ---
# avec standardisation et pca :  0.9643255295429208
# knn seul :  0.9464882943143813
# *********************** 4 ***********************
# --- TRAIN ---
# avec standardisation et pca :  0.9768479776847978
# knn seul :  0.9676429567642957
# --- TEST ---
# avec standardisation et pca :  0.9620958751393534
# knn seul :  0.9442586399108138
# *********************** 5 ***********************
# --- TRAIN ---
# avec standardisation et pca :  0.9757322175732217
# knn seul :  0.9676429567642957
# --- TEST ---
# avec standardisation et pca :  0.9643255295429208
# knn seul :  0.947603121516165
# *********************** 6 ***********************
# --- TRAIN ---
# avec standardisation et pca :  0.9712691771269177
# knn seul :  0.9651324965132496
# --- TEST ---
# avec standardisation et pca :  0.9609810479375697
# knn seul :  0.9498327759197325
# *********************** 7 ***********************
# --- TRAIN ---
# avec standardisation et pca :  0.9712691771269177
# knn seul :  0.9642956764295676
# --- TEST ---
# avec standardisation et pca :  0.959866220735786
# knn seul :  0.9498327759197325
# *********************** 8 ***********************
# --- TRAIN ---
# avec standardisation et pca :  0.9701534170153417
# knn seul :  0.9617852161785216
# --- TEST ---
# avec standardisation et pca :  0.9587513935340022
# knn seul :  0.9487179487179487
# *********************** 9 ***********************
# --- TRAIN ---
# avec standardisation et pca :  0.9695955369595537
# knn seul :  0.9617852161785216
# --- TEST ---
# avec standardisation et pca :  0.9576365663322185
# knn seul :  0.9453734671125975
